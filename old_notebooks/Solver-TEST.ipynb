# %%
'''
User specs
'''
stay_duration = 1.75 * 60 #In minutes
p_budget = 6.00 #dollars

variables = {
    'y_1': {'b_1': 1.0,
          'constraint_coeffs':
            {'parking_fee': 3.5,
           'expected_avail': 0,
           'et_next_out': 17.0,'et_next_in': 27.0,
           'walk_time': 5.0,'travel_et': 25.0}},
    
    'y_2': {'b_2': 1.0,
          'constraint_coeffs':
            {'parking_fee': 5.5,
           'expected_avail': 0,
           'et_next_out': 5.0, 'et_next_in': 27.0,
           'walk_time': 3.0,'travel_et': 24.0}},
    
    'y_3': {'b_3': 1.0,
          'constraint_coeffs':
            {'parking_fee': 6.5,
           'expected_avail':0,
           'et_next_out': 27.0,'et_next_in': 27.0,
           'walk_time': 8.233, 'travel_et': 18.0}},
}

for k in variables:
    variables[k]['constraint_coeffs']['savings'] = p_budget - variables[k]['constraint_coeffs']['parking_fee']

# %% [markdown]
# # Test Cases

# %%
test_cases = {
     #Based on travel times
    "travel_et_1": {
                    'y_1': {'b_1': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 2,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}},

                    'y_2': {'b_2': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 2,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 35.0}},
        
                    'y_3': {'b_3': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 2,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 38.0}}
                    },
    
    #Availabilities
    "avail_1":{
                    'y_1': {'b_1': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 2,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}},

                    'y_2': {'b_2': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 4,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}},
        
                    'y_3': {'b_3': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 3,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}}
                    },
    
    #Availabilities
    "avail_2":{
                    'y_1': {'b_1': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 2,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 10.0, 'travel_et': 25.0}},

                    'y_2': {'b_2': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 3.5,
                           'expected_avail': 4,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}},
        
                    'y_3': {'b_3': 1.0,
                          'constraint_coeffs':
                            {'parking_fee': 2.5,
                           'expected_avail': 3,
                           'et_next_out': 10.0, 'et_next_in': 11.0,
                           'walk_time': 5.0, 'travel_et': 25.0}}
                    }
}

variables = test_cases["avail_2"]
for k in variables:
    variables[k]['constraint_coeffs']['savings'] = p_budget - variables[k]['constraint_coeffs']['parking_fee']

# %%
from utils.solver import *

solver = Solver(variables)
solver.solve_LP()
soln = solver.get_soln_summary()
soln
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ahnafayub/opt/anaconda3/envs/geodat/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/52/md6yz3dn2g344wf8pqqb7kc80000gn/T/60659ac81c2341f9b2d1497d448e303b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/52/md6yz3dn2g344wf8pqqb7kc80000gn/T/60659ac81c2341f9b2d1497d448e303b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 29 RHS
# At line 35 BOUNDS
# At line 39 ENDATA
# Problem MODEL has 5 rows, 3 columns and 15 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 3 (0) columns and 15 (0) elements
# 0  Obj 0 Primal inf 1.5595236 (2)
# 2  Obj 0.8974359
# Optimal - objective value 0.8974359
# Optimal objective 0.8974358974 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# ...

# %%
solver.soln_status
# Out:
# 'Optimal'
